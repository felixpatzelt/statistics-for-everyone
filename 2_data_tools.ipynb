# %% [markdown]
# # The Tools of the Trade

# %%
import numpy as np
import pandas as pd
import altair as alt
from helpers.svg_wrapper import SVGImg
import helpers.plotting as pt
pt.enable_slide_theme()
pt.import_slide_theme_font_in_notebook()
# Out:
# <link rel="stylesheet" type="text/css" href="./reveal.js/dist/theme/fonts/source-sans-pro/source-sans-pro.css">

# %% [markdown]
# ## There are vast amounts of tools for working with data
# ###

# %% [markdown]
# - Analog physical tools have been mostly replaced by computers 📝⌨️
# - In 2025, any computer has the power to do a lot with data. 💻
#     - Much easier if your data fits in RAM!
# - Many of the most used software tools are open source 🐧

# %% [markdown]
# <a title="EvanLovely from Portland, OR, USA (image on display: Chi King), CC BY 2.0 &lt;https://creativecommons.org/licenses/by/2.0&gt;, via Wikimedia Commons" href="https://commons.wikimedia.org/wiki/File:Computer_Using_Cat.jpg"><img width="512" alt="Computer Using Cat" src="https://upload.wikimedia.org/wikipedia/commons/thumb/6/63/Computer_Using_Cat.jpg/512px-Computer_Using_Cat.jpg?20190118213855"></a>
# <small>Photo by EvanLovely via Wikimedia Commons</small>

# %% [markdown]
# ### Any programming language can do
# - Especially in research and production Python dominates 🐍
# - In statistics & analytics, R is still popular 📊
# - JavaScript for purely web-focused use cases 🌐
# - Compiled languages are used rather for low-level library development or classic app development
# - Many specialised languages exist smaller but active communities

# %% [markdown]
# ```python
# def say_hello(name):
#     print("Hello", name)
#
# say_hello("World")
# ```
#
# <small>Python is very popular in data science<small>

# %% [markdown]
# ### There are also graphical tools with more limited capabilities
# - Business reporting (Tableau, PowerBI, Metabase) 👔
# - Operations Dashboarding (Grafana, DataDog)
# - Statistics (SPSS)
# - Spreadsheets (Excel, LibreOffice)
# - …

# %% [markdown]
# ### In research and applications Python dominates

# %% [markdown]
# - Replaced Matlab etc. in Science & Engineering 👩‍🔬👷
# - Became the dominant ecosystem<br> for Data Science & AI 🦾
# - Low-level code is often written in C/C++/Fortran/Rust but this is hardly ever needed for applied uses

# %% [markdown]
# <img src="https://jupyter.org/assets/homepage/labpreview.webp">
# <small>In the last decade, notebooks became the dominant working environment for data scientists (above: <a href="https://jupyter.org">jupyter</a>)</small>

# %% [markdown]
# ### Notes on Python performance
#
# - Often brought up but usually it is more than fast enough 😱
# - The interpreter really isn't that fast 🐌
# - Standard library and high performance frameworks do the heavy lifting 🏋️
# - Ease of use and community size make it worth 🤝

# %% [markdown]
# ### The real issue
#
# - Many different ways to do the same thing
# - So many libraries to choose from

# %% [markdown]
# ### Some of the most popular computing frameworks

# %% [markdown]
# - The standard library (it is really good)
# - [NumPy](NumPy): high performance numerical data structures, foundation for a lot
# - [SciPy](https://scipy.org): fundamental numerical algorythms
# - [ScikitLearn](http://scikit-learn.org): classic machine learning
# - [Statsmodels](https://www.statsmodels.org): classic statistical models inspired by R
# - [Pandas](https://pandas.pydata.org): DataFrames for working with tabular data and time series, also inspired by R
# - [PyTorch](https://pytorch.org) & [Tensorflow](https://www.tensorflow.org): deep learning, used to build ChatGPT & Co

# %% [markdown]
# <a title="BrunelloN, CC BY-SA 4.0 &lt;https://creativecommons.org/licenses/by-sa/4.0&gt;, via Wikimedia Commons" href="https://commons.wikimedia.org/wiki/File:Example_of_a_deep_neural_network.png"><img width="512" alt="An example of the structure of a deep neural network." src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Example_of_a_deep_neural_network.png/512px-Example_of_a_deep_neural_network.png?20210813150620"></a>
# <small>Architecture of a deep neuronal network. Figure by BrunelloN via Wikimedia commons.</small>

# %% [markdown]
# ### Some of the most popular visualisation frameworks

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)

# some random data
x = np.random.randn(1000)
y = np.random.randn(1000)


def scatter_hist(x, y, ax, ax_histx, ax_histy):
    # no labels
    ax_histx.tick_params(axis="x", labelbottom=False)
    ax_histy.tick_params(axis="y", labelleft=False)

    # the scatter plot:
    ax.scatter(x, y, alpha=0.5)

    # now determine nice limits by hand:
    binwidth = 0.25
    xymax = max(np.max(np.abs(x)), np.max(np.abs(y)))
    lim = (int(xymax/binwidth) + 1) * binwidth

    bins = np.arange(-lim, lim + binwidth, binwidth)
    ax_histx.hist(x, bins=bins, color='C1')
    ax_histy.hist(y, bins=bins, orientation='horizontal', color='C2')
    
fig, axs = plt.subplot_mosaic([['histx', '.'],
                               ['scatter', 'histy']],
                              figsize=(6, 6),
                              width_ratios=(4, 1), height_ratios=(1, 4),
                              layout='constrained')
scatter_hist(x, y, axs['scatter'], axs['histx'], axs['histy'])
axs['scatter'].set_xlabel('x')
axs['scatter'].set_ylabel('y')
fig.suptitle("Matplotlib - the OG python plotting library");

# %% [markdown]
# - [Matplotlib](https://matplotlib.org): the oldest and most used plotting lib
# - [Altair](https://altair-viz.github.io): python binding for the platform independent nice & semantic visualisation standard [Vega](https://vega.github.io/vega-lite/). Used in the slides you saw today.
# - [Plotly](https://plotly.com) another very popular framework (I don't use it)

# %% [markdown]
# ## What we will do in the Data-Camp:

# %% [markdown]
# - **Understand** the relevant theory 🎓
# - Get **hands-on** 🧑🏽‍💻
#     - Install python & framworks
#     - Load and analyse Data interactively in a notebook
#     - Train an ML model
#     - ... open to suggestions!

# %% [markdown]
# <a title="© User:Colin / Wikimedia Commons" href="https://commons.wikimedia.org/wiki/File:Backlit_keyboard.jpg"><img width="512" alt="A backlit laptop computer keyboard being used." src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Backlit_keyboard.jpg/512px-Backlit_keyboard.jpg?20131226192710"></a>
# <small>A backlit Keyboard, picture by Colin via Wikimedia Commons</small>

# %% [markdown]
# <small>If you want to you can just attend the theory part</small>

# %% [markdown]
# [Follow this link to get to the next session!](3_practical_basics.slides.html)
